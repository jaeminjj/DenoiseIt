# %%
import os
import sys
import pandas as pd

# %%
os.chdir('/data1/projects/2021_MOPA/SMALL_NMF_V2/github/')

# %%
os.chdir("./code/")
import isoNMF as ISO
# Out:
# /data1/home/jaeminjj/.local/lib/python3.8/site-packages/numba/core/errors.py:175: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
os.chdir('/data1/projects/2021_MOPA/SMALL_NMF_V2/github/')

# %%
full_data=pd.read_csv('data/gene_matrix.csv') ### 56602
sample_label=pd.read_csv('data/sample_label.csv')

# %%
##########################################
###  NMF_Bulk_gene_remove(data,normalization,rank,outdirectory,filename,threshold(float))
### rank : recommend to be 120 ~ 160
### normalization : norm - quantile normalization
###                log_norm - 'log2 normalization'
##                 TMM - trimmed mean of M-values normalization 
### threshold (float) : p-value recommend to be 0.05 ~ 0.001 
##########################################

# %%
filtered_data=ISO.NMF_Bulk_gene_remove(full_data,'norm',120,'result','result',0.05)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# KeyboardInterrupt

# %%
filtered_data

# %%
inlier_genes=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/COAD_filter_paper/full/remain_genes/NMF_norm_10_360_0.001/0.csv')

# %%
data=full_data[full_data['ID'].isin(inlier_genes.iloc[:,0])]

# %%
ISO.draw_umap_for_paper(data,sample_label,'result/','umap')

# %%
    full_data=full_data.iloc[:,1:]
    #embedding_gene_corr_full = umap.UMAP(n_neighbors=10,
    #                  min_dist=0.1).fit_transform(reverse(full_data))
    a=proc_qnorm(full_data)
    full_data1=proc_scale(a)
    matrix=reverse(full_data1).copy()
    embedding_gene_corr_full = umap.UMAP().fit_transform(matrix)
    plot=pd.DataFrame(index=range(len(embedding_gene_corr_full)),columns =['x','y','type'])
    plot['x']=embedding_gene_corr_full[:,0]
    plot['y']=embedding_gene_corr_full[:,1]
    plot['type']=sample_label['Subtype'].to_list()
    if len(sample_label['Subtype'].unique())==2:
        umall=sns.scatterplot(x='x',y='y',hue='type',data=plot,s=90,palette=["#2c7fb8", "#f03b20"],linewidth=0)
    if len(sample_label['Subtype'].unique())==3:
        umall=sns.scatterplot(x='x',y='y',hue='type',data=plot,s=90,palette=["#2c7fb8", "#7fcdbb", "#edf8b1"],linewidth=0)
    if len(sample_label['Subtype'].unique())==4:
        umall=sns.scatterplot(x='x',y='y',hue='type',data=plot,s=90,palette=["#2c7fb8", "#7fcdbb", "#edf8b1", "#f03b20"],linewidth=0)
    if len(sample_label['Subtype'].unique())==8:
        umall=sns.scatterplot(x='x',y='y',hue='type',data=plot,s=90,palette=['#F8766D', '#F17CBE', '#7CE88D', '#00BFC4','red'],linewidth=0)
        #umall=sns.scatterplot(x='x',y='y',hue='type',data=plot,s=90,palette=['red','#ff7f0e','#2ca02c','#F25F5C','#247BA0','#70C1B3','#50514F','#628B48'],linewidth=0)
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    umall = umall.get_figure()
    fig_size = (12, 12)
    umall.set_size_inches(fig_size)
    

    umall.savefig(path+'/'+folder_name+'.pdf')
    plt.clf()

# %%
NMR.ARI(fl,sample_label_v2,inlier_genes)

# %%
 


data_types = 5*['COVID_BULK']
data_typs=os.listdir('/data1/projects/2021_MOPA/SMALL_NMF_V2/data/COVID_paper/')
data_typs.remove(".ipynb_checkpoints")

data_typs1 = 5*['COVID_paper/']
a=list()
for i,j in zip(data_typs1,data_typs):
    a.append(i+j)
data_types1 = 5*['COVID_']    
data_types3 = 5*['_paper']    
b=list()
for i,j,k in zip(data_types1,data_typs,data_types3):
    b.append(i+j+k)    
    
data_typs=a.copy()
data_types=b.copy()
path='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'
sub_sample='full'
method='NMF'
data_types1 = ['STAD_paper','LUAD_paper','COAD_filter_paper','BRCA_filter_paper']
data_typs1 = ['TCGA/STAD','TCGA/LUAD','TCGA/COAD_filter','TCGA/BRCA_filter']
data_types1 = ['STAD_paper','LUAD_paper','COAD_filter_paper','BRCA_filter_paper']
data_typs1 = ['TCGA/STAD','TCGA/LUAD','TCGA/COAD_filter','TCGA/BRCA_filter']
data_types=data_types1+data_types
data_typs=data_typs1+data_typs
path='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'
sub_sample='full'
method='NMF'
NMF_list=list()
for i in os.listdir('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/BRCA_paper/full/remain_genes/'):
    if i.startswith('NMF'):
        NMF_list.append(i)
num=0
path='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'
sub_sample='full'
method='NMF'
         
path='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'
sub_sample='full'
method='NMF'
#for data_type,data_typ in zip(data_types,data_typs):
#    num=0
#    methods=os.listdir('/data/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/')
#    #methods=['NMF_norm_10_360_0.001','full_genes','noisyR','full_genes','PCA_norm_10_360_0.001']
#    for method in methods:
#        full_data=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/gene_matrix.csv') ### 56602
#        sample_label=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/subtype.csv')
#        if method == '.ipynb_checkpoints':
#            continue
#        ARI_score=pd.DataFrame()
#        ARI_score['method'] = ['kmeans_ARI','shilleutte_score','hierarchical_ARI','remain_genes']
#        outdir_name=method
#        outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/remain_genes/'+outdir_name
#        inlier_genes=pd.read_csv(outdir+'/0.csv')
#        inlier_genes=inlier_genes.iloc[:,0]
#        df=pd.DataFrame(data=full_data[full_data.iloc[:,0].isin(set(inlier_genes))].mean(axis=1))
#        t=NMR.draw_umap(full_data,sample_label,path,data_type,sub_sample,method,num)
#data_types=data_types1+data_types
#data_typs=data_typs1+data_typs
data_types = ['STAD_paper','LUAD_paper','COAD_filter_paper','BRCA_filter_paper']
data_typs = ['TCGA/STAD','TCGA/LUAD','TCGA/COAD_filter','TCGA/BRCA_filter']
path='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'
sub_sample='full'
#method='NMF'
#files
for data_type,data_typ in zip(data_types,data_typs):
    files=['NMF_norm_10_360_0.001']
    for file in files:
        if 'NMF' in file:
            print(file)
            file.split('_')[-1]
            p_value=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_p_value_0.csv')
            outlier_score=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_score_list_0.csv')
            outlier_score=outlier_score.loc[p_value[p_value.iloc[:,0]<float(file.split('_')[-1])].index,:].sort_values('0',ascending=False)
            outlier_score=outlier_score.drop_duplicates('sample')
            full_data=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/gene_matrix.csv') ### 56602
            sample_label=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/subtype.csv') ### label data
            sample_label.columns=['sample','type']
            outlier_samples=list()
            remain_genes=list()
            # odd -> sample 제거 , even -> gene 제거
            i=0
            p_value=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_p_value_'+str(i)+'.csv')
            outlier_score=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_score_list_'+str(i)+'.csv')
            outlier_score=outlier_score.loc[p_value[p_value.iloc[:,0]<float(file.split('_')[-1])].index,:].sort_values('0',ascending=False)
            outlier_score=outlier_score.drop_duplicates('sample')                  
            
            #sample_label=sample_label.loc[~sample_label.index.isin(outlier_score.iloc[:5,1]),:]
            full_data=pd.concat([full_data.iloc[:,0],full_data.loc[:,sample_label['sample']]],axis=1)
            
            outdir_name =file
            outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/remain_genes/'+outdir_name
            mean_value=full_data.iloc[:,1:].mean(axis=1)
            mean_value = pd.DataFrame(data= mean_value)
            min_num=file.split('_')[2]
            full_data=full_data.iloc[mean_value[mean_value[0]>float(min_num)].index,:].copy()
            
            remain_genes=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+
                                      file+'/0.csv')
                #print(len(remain_genes.iloc[:,0]))
            #inlier_gene_set=list(remain_genes.iloc[:,0])
            #full_data=full_data.loc[remain_genes.iloc[:,0],:]
            full_data=full_data[full_data.iloc[:,0].isin(remain_genes.iloc[:,0])]
            
            inlier_gene_set=set()
            sample_set=set()
            inlier_gene_set=list(full_data.iloc[:,0])
            sample_set=sample_label.iloc[:,0]     
            sample_set=pd.DataFrame(sample_set)
            
            rank=file.split('_')[3]
            normalization=file.split('_')[1]
            thres=float(file.split('_')[-1])
            inlier_gene_set=full_data.iloc[:,0]
            #full_data=pd.concat([full_data.iloc[:,0],full_data.loc[inlier_gene_set,:]],axis=1)

            a=['g1','g2','g3','g4','g5']
            for i in a:
                print(i)
                outdir_name=file
                outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/remain_genes/'+outdir_name
                print(outdir)
                print(thres)
                print(data_type)          
                NMR.NMF_Bulk_gene_remove(full_data,normalization,int(rank),outdir,i,thres)
                remain_genes=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/'+str(i)+'.csv')
                print(len(remain_genes.iloc[:,0]))
                inlier_gene_set=list(remain_genes.iloc[:,0])
                full_data=full_data.loc[remain_genes.iloc[:,0],:]
                
                print(full_data)
                
                
                #if len(remain_genes.iloc[:,0])<1000:
                #    break
                #outdir_name =file.copy()
 
                tt=random_sampling(sample_set)
                ARI_score=pd.DataFrame()
                ARI_score['method'] = ['kmeans_ARI','shilleutte_score','hierarchical_ARI','remain_genes']
                outdir_name=file
                outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/remain_genes/'+outdir_name
                #inlier_genes=pd.read_csv(outdir+'/0.csv')
                remain_genes=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/'+str(i)+'.csv')
                inlier_genes=remain_genes.iloc[:,0]
                #if len(inlier_genes.iloc[:,0])<3000:
                #        break  
                #inlier_genes=inlier_genes.iloc[:,0]
 
                #df=pd.DataFrame(data=full_data[full_data.iloc[:,0].isin(set(inlier_genes))].mean(axis=1))
                
                #if os.path.isfile(file_path):
                #    print("File exists!")
                
                
                ARI_k=list()
                ARI_s = list()
                ARI_h =list()
                numm=0
                
                print(len(inlier_gene_set))
                print(len(sample_set.iloc[:,0]))
                for random_sample in tt:
                    #full_data=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/gene_matrix.csv') ### 56602

                    sample_label_v2 = sample_label[sample_label.iloc[:,0].isin(random_sample)]
                    sample_label_v2.columns=['sample','Subtype']
                    fl=pd.concat([full_data.iloc[:,0:1],full_data[sample_label_v2.iloc[:,0]]],axis=1)
                    t=NMR.ARI(fl,sample_label_v2,inlier_genes)
                    t=list(t)
                    t=t[:-1]
                    t.append(len(inlier_genes))
                    print(t)
                    ARI_score['score'+str(num)]=list(t)
                    num+=1
                outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/ARI/'+file
                ARI_score.to_csv(outdir+'/'+str(i)+'.csv',index=False)
                
                
                #t=NMR.draw_umap(fl,sample_label_v2,path,data_type,sub_sample,file,str(i))

data_types = 5*['COVID_BULK']
data_typs=os.listdir('/data1/projects/2021_MOPA/SMALL_NMF_V2/data/COVID_paper/')
data_typs.remove(".ipynb_checkpoints")

data_typs1 = 5*['COVID_paper/']
a=list()
for i,j in zip(data_typs1,data_typs):
    a.append(i+j)
data_types1 = 5*['COVID_']    
data_types3 = 5*['_paper']    
b=list()
for i,j,k in zip(data_types1,data_typs,data_types3):
    b.append(i+j+k)    
    
data_typs=a.copy()
data_types=b.copy()
                
                
for data_type,data_typ in zip(data_types,data_typs):
    files=['NMF_norm_5_360_0.05']
    for file in files:
        if 'NMF' in file:
            print(file)
            file.split('_')[-1]
            p_value=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_p_value_0.csv')
            outlier_score=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_score_list_0.csv')
            outlier_score=outlier_score.loc[p_value[p_value.iloc[:,0]<float(file.split('_')[-1])].index,:].sort_values('0',ascending=False)
            outlier_score=outlier_score.drop_duplicates('sample')
            full_data=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/gene_matrix.csv') ### 56602
            sample_label=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/subtype.csv') ### label data
            sample_label.columns=['sample','type']
            outlier_samples=list()
            remain_genes=list()
            # odd -> sample 제거 , even -> gene 제거
            i=0
            p_value=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_p_value_'+str(i)+'.csv')
            outlier_score=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/outlier_score_list_'+str(i)+'.csv')
            outlier_score=outlier_score.loc[p_value[p_value.iloc[:,0]<float(file.split('_')[-1])].index,:].sort_values('0',ascending=False)
            outlier_score=outlier_score.drop_duplicates('sample')                  
            
            #sample_label=sample_label.loc[~sample_label.index.isin(outlier_score.iloc[:5,1]),:]
            full_data=pd.concat([full_data.iloc[:,0],full_data.loc[:,sample_label['sample']]],axis=1)
            
            outdir_name =file
            outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/remain_genes/'+outdir_name
            mean_value=full_data.iloc[:,1:].mean(axis=1)
            mean_value = pd.DataFrame(data= mean_value)
            min_num=file.split('_')[2]
            full_data=full_data.iloc[mean_value[mean_value[0]>float(min_num)].index,:].copy()
            
            remain_genes=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+
                                      file+'/0.csv')
                #print(len(remain_genes.iloc[:,0]))
            #inlier_gene_set=list(remain_genes.iloc[:,0])
            #full_data=full_data.loc[remain_genes.iloc[:,0],:]
            full_data=full_data[full_data.iloc[:,0].isin(remain_genes.iloc[:,0])]
            
            inlier_gene_set=set()
            sample_set=set()
            inlier_gene_set=list(full_data.iloc[:,0])
            sample_set=sample_label.iloc[:,0]     
            sample_set=pd.DataFrame(sample_set)
            
            rank=file.split('_')[3]
            normalization=file.split('_')[1]
            thres=float(file.split('_')[-1])
            inlier_gene_set=full_data.iloc[:,0]
            #full_data=pd.concat([full_data.iloc[:,0],full_data.loc[inlier_gene_set,:]],axis=1)

            a=['g1','g2','g3','g4','g5']
            for i in a:
                print(i)
                outdir_name=file
                outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/remain_genes/'+outdir_name
                print(outdir)
                print(thres)
                print(data_type)          
                NMR.NMF_Bulk_gene_remove(full_data,normalization,int(rank),outdir,i,thres)
                remain_genes=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/'+str(i)+'.csv')
                print(len(remain_genes.iloc[:,0]))
                inlier_gene_set=list(remain_genes.iloc[:,0])
                full_data=full_data.loc[remain_genes.iloc[:,0],:]
                
                print(full_data)
                
                
                #if len(remain_genes.iloc[:,0])<1000:
                #    break
                #outdir_name =file.copy()
 
                tt=random_sampling(sample_set)
                ARI_score=pd.DataFrame()
                ARI_score['method'] = ['kmeans_ARI','shilleutte_score','hierarchical_ARI','remain_genes']
                outdir_name=file
                outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/remain_genes/'+outdir_name
                #inlier_genes=pd.read_csv(outdir+'/0.csv')
                remain_genes=pd.read_csv('/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/full/remain_genes/'+file+'/'+str(i)+'.csv')
                inlier_genes=remain_genes.iloc[:,0]
                #if len(inlier_genes.iloc[:,0])<3000:
                #        break  
                #inlier_genes=inlier_genes.iloc[:,0]
 
                #df=pd.DataFrame(data=full_data[full_data.iloc[:,0].isin(set(inlier_genes))].mean(axis=1))
                
                #if os.path.isfile(file_path):
                #    print("File exists!")
                
                
                ARI_k=list()
                ARI_s = list()
                ARI_h =list()
                numm=0
                
                print(len(inlier_gene_set))
                print(len(sample_set.iloc[:,0]))
                for random_sample in tt:
                    #full_data=pd.read_csv('/data/projects/2021_MOPA/SMALL_NMF_V2/data/'+data_typ+'/full_data/gene_matrix.csv') ### 56602

                    sample_label_v2 = sample_label[sample_label.iloc[:,0].isin(random_sample)]
                    sample_label_v2.columns=['sample','Subtype']
                    fl=pd.concat([full_data.iloc[:,0:1],full_data[sample_label_v2.iloc[:,0]]],axis=1)
                    t=NMR.ARI(fl,sample_label_v2,inlier_genes)
                    t=list(t)
                    t=t[:-1]
                    t.append(len(inlier_genes))
                    print(t)
                    ARI_score['score'+str(num)]=list(t)
                    num+=1
                outdir='/data1/projects/2021_MOPA/SMALL_NMF_V2/result/'+data_type+'/'+str(sub_sample)+'/ARI/'+file
                ARI_score.to_csv(outdir+'/'+str(i)+'.csv',index=False)
