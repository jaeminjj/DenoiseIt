# %%
import os
import sys
import pandas as pd

# %%
os.chdir('/data1/projects/2021_MOPA/SMALL_NMF_V2/github/')

# %%
os.chdir("./code/")
import isoNMF as ISO
# Out:
# /data1/home/jaeminjj/.local/lib/python3.8/site-packages/numba/core/errors.py:175: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
full_data=pd.read_csv('data/gene_matrix.csv') ### 56602
sample_label=pd.read_csv('data/sample_label.csv')

# %%
##########################################
###  NMF_Bulk_gene_remove(data,normalization,rank,outdirectory,filename,threshold(float))
### rank : recommend to be 120 ~ 160
### normalization : norm - quantile normalization
###                log_norm - 'log2 normalization'
##                 TMM - trimmed mean of M-values normalization 
### threshold (float) : p-value recommend to be 0.05 ~ 0.001 
##########################################

# %%
filtered_data=ISO.NMF_Bulk_gene_remove(full_data,'norm',120,'result','result',0.05)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# KeyboardInterrupt

# %%
data=filtered_data

# %%
ISO.draw_umap_for_paper(data,sample_label,'result/','umap')
